# %%
using PyPlot
using LinearAlgebra

# %%
function affine_scaling(c,A,b, x0; beta = 0.5, epsilon = 1e-9, max_iter = 1000)
    
    x1_traj = []
    x2_traj = []
    
    x = x0
    
    for i in 1:max_iter
        push!(x1_traj, x[1])
        push!(x2_traj, x[2])
        
        X = Diagonal(x)
        p = inv(A*X^2*A')*A*X^2*c
        r = c-A'*p
        
        if minimum(r) >= 0 && dot(x,r) < epsilon
            break
        end
        
        x = x - beta* X^2*r/norm(X*r)
    end
   
    
    return x1_traj,x2_traj

end

# %%
#=

=#

c=[-3,-2, 0, 0 ]
A=[
2 1 1 0 ;
1 2 0 1
]

b=[6 ,6]

x1 = 2.5
x2 = 0.1
x0 = [x1,x2, 6-2*x1-1*x2,6-1*x1-2*x2]

# %%
function primal_path_following(c,A,b, x0; mu=0.9, alpha=0.9, epsilon = 1e-9, max_iter = 1000)
    x1_traj = []
    x2_traj = []
    
    x = x0
    e = ones(length(x),1)
    n = length(x)
    m = length(b)
    
    for i = 1:max_iter
        push!(x1_traj, x[1])
        push!(x2_traj, x[2])
        
        X = Diagonal(x)
        mu = alpha * mu
        
        LHS = [mu*inv(X)^2      -A'      ;
                A             zeros(m,m)  ]
        
        
        RHS = [mu*inv(X)*e - c ;
             zeros(m,1)]
        sol = LHS \ RHS
        
        d = sol[1:n]
        p = sol[n+1:end]
        x = x+d
        s = c -A'*p
        
        if dot(s,x) < epsilon
            break
        end
    end

    return x1_traj, x2_traj
    
end

# %%
using LinearAlgebra

function primal_path_following(c,A,b,x0;
            mu=0.9, alpha=0.9, epsilon=1e-9, max_iter=1000)
  # Preparing variables for the trajectories
  x1_traj = []
  x2_traj = []

  # Initialization
  x = x0
  e = ones(length(x),1)
  n = length(x)
  m = length(b)

  for i=1:max_iter
    # Recording the trajectories of x1 and x2
    push!(x1_traj, x[1])
    push!(x2_traj, x[2])

    # Computing
    X = Diagonal(x)
    mu = alpha * mu

    # Solving the linear system
    LHS = [ mu*inv(X)^2       -A'     ;
               A          zeros(m,m)  ]
    RHS = [ mu*inv(X)*e - c ;
            zeros(m,1) ]
    sol = LHS \ RHS

    # Update
    d = sol[1:n]
    p = sol[n+1:end]
    x = x + d
    s = c - A'*p

    # Optimality check
    if dot(s,x) < epsilon
      break
    end
  end

  return x1_traj, x2_traj
end

# %%
#=

=#

c=[-8, -5, 0, 0, 0, 0 ]
A=[
2 4 1 0 0 0;
1 -3  0 1 0 0;
2 -1  0 0 1 0;
-1 4  0 0 0 1
]

b=[80, 4, 20, 40 ]

x1 = 2.93
x2 = 1.08
x0 = [x1,x2,80-(4*x2+2*x1),4-(-3*x2+1*x1),
    20-(-1*x2+2*x1), 40-(4*x2-1*x1)]

x1_traj_a,x2_traj_a = affine_scaling(c,A,b, x0)

x1_traj_p,x2_traj_p = primal_path_following(c,A,b, x0)
fig = figure()
plot(x1_traj_a,x2_traj_a,"o-", label = "Affine")

plot(x1_traj_p,x2_traj_p,"*-", label = "primal")
legend(loc = "upper right")

# %%
#=

for j in 0.1:0.1:10
    x1 =  j
        print(x1)
    for i  in 0.1:0.1:10

        x2 =  i
        print(x2)
        x1_traj_p,x2_traj_p = primal_path_following(c,A,b, x0)
        print(x1_traj_p,x2_traj_p)
        println("           ")
        print(plot(x1_traj_p,x2_traj_p,"*-", label = "primal"))
    end
end

=#
# Out:
# 0.10.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D456E30>]0.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D457100>]0.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4573A0>]0.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D457640>]0.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4578E0>]0.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D457B80>]0.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D457E20>]0.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47C100>]0.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47C3A0>]1.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47C640>]1.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D456E60>]1.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47CB50>]1.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47CDF0>]1.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47D090>]1.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47D330>]1.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47D5D0>]1.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47D870>]1.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47DB10>]1.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47DDB0>]2.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47E050>]2.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4551B0>]2.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47E350>]2.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47E5F0>]2.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47E890>]2.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47EB30>]2.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47EDD0>]2.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47F070>]2.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47F310>]2.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47F5B0>]3.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47F850>]3.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47FAF0>]3.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D47FD90>]3.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B0070>]3.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B0310>]3.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B05B0>]3.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B0850>]3.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B0AF0>]3.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B0D90>]3.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B1030>]4.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B12D0>]4.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B1570>]4.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B1810>]4.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B1AB0>]4.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B1D50>]4.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B1FF0>]4.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B2290>]4.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B2530>]4.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B27D0>]4.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B2A70>]5.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B2D10>]5.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B2FB0>]5.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B3250>]5.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B34F0>]5.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B3790>]5.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B3A30>]5.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B3CD0>]5.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4B3F70>]5.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A4250>]5.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A44F0>]6.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A4790>]6.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A4A30>]6.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A4CD0>]6.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A4F70>]6.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A5210>]6.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A54B0>]6.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A5750>]6.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A59F0>]6.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A5C90>]6.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A5F30>]7.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A61D0>]7.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A6470>]7.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A6710>]7.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A69B0>]7.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A6C50>]7.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A6EF0>]7.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A7190>]7.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A7430>]7.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A76D0>]7.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A7970>]8.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A7C10>]8.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7A7EB0>]8.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7D8190>]8.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7D8430>]8.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7D86D0>]8.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7D8970>]8.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7D8C10>]8.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7D8EB0>]8.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7D9150>]8.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7D93F0>]9.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7D9690>]9.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7D9930>]9.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7D9BD0>]9.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7D9E70>]9.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7DA110>]9.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7DA3B0>]9.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7DA650>]9.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7DA8F0>]9.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7DAB90>]9.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7DAE30>]10.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7DB0D0>]0.20.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7DB370>]0.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7DB610>]0.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7DB8B0>]0.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7DBB50>]0.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C7DBDF0>]0.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8140D0>]0.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C814370>]0.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C814610>]0.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8148B0>]1.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C814B50>]1.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C814DF0>]1.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C815090>]1.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C815330>]1.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8155D0>]1.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C815870>]1.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C815B10>]1.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C815DB0>]1.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C816050>]1.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8162F0>]2.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C816590>]2.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C816830>]2.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C816AD0>]2.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C816D70>]2.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C817010>]2.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8172B0>]2.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C817550>]2.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8177F0>]2.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C817A90>]2.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C817D30>]3.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C817FD0>]3.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8402B0>]3.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C840550>]3.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8407F0>]3.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C840A90>]3.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C840D30>]3.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C840FD0>]3.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C841270>]3.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C841510>]3.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8417B0>]4.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C841A50>]4.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C841CF0>]4.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C841F90>]4.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C842230>]4.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8424D0>]4.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C842770>]4.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C842A10>]4.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C842CB0>]4.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C842F50>]4.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8431F0>]5.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C843490>]5.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C843730>]5.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8439D0>]5.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C843C70>]5.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C843F10>]5.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8781F0>]5.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C878490>]5.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C878730>]5.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8789D0>]5.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C878C70>]6.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C878F10>]6.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8791B0>]6.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C879450>]6.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C8796F0>]6.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C879990>]6.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C879C30>]6.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C879ED0>]6.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C87A170>]6.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C87A410>]6.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C87A6B0>]7.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C87A950>]7.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C87ABF0>]7.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C87AE90>]7.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C87B130>]7.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C87B3D0>]7.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C87B670>]7.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C87B910>]7.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C87BBB0>]7.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1C87BE50>]7.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4E8130>]8.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4E83D0>]8.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4E8670>]8.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4E8910>]8.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4E8BB0>]8.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4E8E50>]8.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4E90F0>]8.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4E9390>]8.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4E9630>]8.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4E98D0>]8.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4E9B70>]9.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4E9E10>]9.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4EA0B0>]9.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4EA350>]9.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4EA5F0>]9.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4EA890>]9.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4EAB30>]9.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4EADD0>]9.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4EB070>]9.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4EB310>]9.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4EB5B0>]10.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4EB850>]0.30.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4EBAF0>]0.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D4EBD90>]0.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D520070>]0.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D520310>]0.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5205B0>]0.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D520850>]0.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D520AF0>]0.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D520D90>]0.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D521030>]1.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5212D0>]1.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D521570>]1.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D521810>]1.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D521AB0>]1.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D521D50>]1.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D521FF0>]1.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D522290>]1.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D522530>]1.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5227D0>]1.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D522A70>]2.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D522D10>]2.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D522FB0>]2.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D523250>]2.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5234F0>]2.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D523790>]2.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D523A30>]2.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D523CD0>]2.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D523F70>]2.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D550250>]2.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5504F0>]3.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D550790>]3.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D550A30>]3.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D550CD0>]3.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D550F70>]3.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D551210>]3.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5514B0>]3.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D551750>]3.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5519F0>]3.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D551C90>]3.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D551F30>]4.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5521D0>]4.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D552470>]4.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D552710>]4.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5529B0>]4.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D552C50>]4.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D552EF0>]4.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D553190>]4.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D553430>]4.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5536D0>]4.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D553970>]5.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D553C10>]5.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D553EB0>]5.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D590190>]5.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D590430>]5.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5906D0>]5.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D590970>]5.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D590C10>]5.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D590EB0>]5.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D591150>]5.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5913F0>]6.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D591690>]6.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D591930>]6.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D591BD0>]6.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D591E70>]6.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D592110>]6.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5923B0>]6.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D592650>]6.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5928F0>]6.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D592B90>]6.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D592E30>]7.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5930D0>]7.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D593370>]7.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D593610>]7.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5938B0>]7.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D593B50>]7.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D593DF0>]7.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CC0D0>]7.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CC370>]7.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CC610>]7.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CC8B0>]8.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CCB50>]8.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CCDF0>]8.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CD090>]8.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CD330>]8.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CD5D0>]8.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CD870>]8.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CDB10>]8.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CDDB0>]8.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CE050>]8.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CE2F0>]9.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CE590>]9.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CE830>]9.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CEAD0>]9.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CED70>]9.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CF010>]9.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CF2B0>]9.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CF550>]9.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CF7F0>]9.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CFA90>]9.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CFD30>]10.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D5CFFD0>]0.40.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6102B0>]0.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D610550>]0.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6107F0>]0.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D610A90>]0.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D610D30>]0.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D610FD0>]0.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D611270>]0.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D611510>]0.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6117B0>]1.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D611A50>]1.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D611CF0>]1.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D611F90>]1.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D612230>]1.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6124D0>]1.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D612770>]1.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D612A10>]1.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D612CB0>]1.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D612F50>]1.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6131F0>]2.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D613490>]2.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D613730>]2.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6139D0>]2.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D613C70>]2.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D613F10>]2.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64C1F0>]2.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64C490>]2.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64C730>]2.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64C9D0>]2.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64CC70>]3.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64CF10>]3.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64D1B0>]3.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64D450>]3.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64D6F0>]3.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64D990>]3.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64DC30>]3.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64DED0>]3.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64E170>]3.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64E410>]3.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64E6B0>]4.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64E950>]4.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64EBF0>]4.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64EE90>]4.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64F130>]4.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64F3D0>]4.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64F670>]4.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64F910>]4.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64FBB0>]4.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D64FE50>]4.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68C130>]5.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68C3D0>]5.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68C670>]5.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68C910>]5.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68CBB0>]5.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68CE50>]5.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68D0F0>]5.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68D390>]5.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68D630>]5.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68D8D0>]5.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68DB70>]6.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68DE10>]6.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68E0B0>]6.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68E350>]6.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68E5F0>]6.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68E890>]6.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68EB30>]6.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68EDD0>]6.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68F070>]6.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68F310>]6.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68F5B0>]7.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68F850>]7.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68FAF0>]7.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D68FD90>]7.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CC070>]7.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CC310>]7.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CC5B0>]7.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CC850>]7.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CCAF0>]7.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CCD90>]7.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CD030>]8.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CD2D0>]8.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CD570>]8.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CD810>]8.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CDAB0>]8.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CDD50>]8.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CDFF0>]8.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CE290>]8.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CE530>]8.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CE7D0>]8.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CEA70>]9.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CED10>]9.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CEFB0>]9.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CF250>]9.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CF4F0>]9.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CF790>]9.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CFA30>]9.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CFCD0>]9.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D6CFF70>]9.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D708250>]9.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D7084F0>]10.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D708790>]0.50.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D708A30>]0.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D708CD0>]0.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D708F70>]0.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D709210>]0.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D7094B0>]0.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D709750>]0.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D7099F0>]0.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D709C90>]0.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D709F30>]1.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D70A1D0>]1.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D70A470>]1.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D70A710>]1.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D70A9B0>]1.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D70AC50>]1.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D70AEF0>]1.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D70B190>]1.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D70B430>]1.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D70B6D0>]1.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D70B970>]2.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D70BC10>]2.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D70BEB0>]2.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D748190>]2.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D748430>]2.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F1D7486D0>]2.5Any[2.93]Any[1.08]
# ...
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D050C0>]9.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D05360>]10.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D05600>]4.60.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D058A0>]0.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D05B40>]0.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D05DE0>]0.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D06080>]0.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D06320>]0.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D065C0>]0.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D06860>]0.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D06B00>]0.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D06DA0>]1.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D07040>]1.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D072E0>]1.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D07580>]1.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D07820>]1.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D07AC0>]1.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D07D60>]1.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D48040>]1.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D482E0>]1.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D48580>]1.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D48820>]2.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D48AC0>]2.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D48D60>]2.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D49000>]2.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D492A0>]2.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D49540>]2.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D497E0>]2.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D49A80>]2.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D49D20>]2.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D49FC0>]2.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D4A260>]3.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D4A500>]3.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D4A7A0>]3.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D4AA40>]3.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D4ACE0>]3.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D4AF80>]3.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D4B220>]3.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D4B4C0>]3.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D4B760>]3.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D4BA00>]3.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D4BCA0>]4.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D4BF40>]4.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D80220>]4.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D804C0>]4.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D80760>]4.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D80A00>]4.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D80CA0>]4.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D80F40>]4.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D811E0>]4.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D81480>]4.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D81720>]5.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D819C0>]5.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D81C60>]5.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D81F00>]5.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D821A0>]5.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D82440>]5.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D826E0>]5.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D82980>]5.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D82C20>]5.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D82EC0>]5.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D83160>]6.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D83400>]6.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D836A0>]6.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D83940>]6.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D83BE0>]6.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20D83E80>]6.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC4160>]6.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC4400>]6.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC46A0>]6.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC4940>]6.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC4BE0>]7.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC4E80>]7.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC5120>]7.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC53C0>]7.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC5660>]7.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC5900>]7.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC5BA0>]7.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC5E40>]7.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC60E0>]7.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC6380>]7.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC6620>]8.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC68C0>]8.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC6B60>]8.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC6E00>]8.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC70A0>]8.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC7340>]8.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC75E0>]8.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC7880>]8.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC7B20>]8.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DC7DC0>]8.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFC0A0>]9.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFC340>]9.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFC5E0>]9.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFC880>]9.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFCB20>]9.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFCDC0>]9.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFD060>]9.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFD300>]9.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFD5A0>]9.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFD840>]9.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFDAE0>]10.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFDD80>]4.70.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFE020>]0.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFE2C0>]0.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFE560>]0.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFE800>]0.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFEAA0>]0.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFED40>]0.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFEFE0>]0.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFF280>]0.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFF520>]1.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFF7C0>]1.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFFA60>]1.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFFD00>]1.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20DFFFA0>]1.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E40280>]1.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E40520>]1.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E407C0>]1.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E40A60>]1.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E40D00>]1.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E40FA0>]2.0Any[2.93]Any[1.08]
# Excessive output truncated after 524296 bytes.
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E41240>]2.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E414E0>]2.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E41780>]2.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E41A20>]2.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E41CC0>]2.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E41F60>]2.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E42200>]2.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E424A0>]2.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E42740>]2.9Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E429E0>]3.0Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E42C80>]3.1Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E42F20>]3.2Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E431C0>]3.3Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E43460>]3.4Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E43700>]3.5Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E439A0>]3.6Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E43C40>]3.7Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E43EE0>]3.8Any[2.93]Any[1.08]
# PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x0000011F20E781C0>]3.9Any
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
x1= 2.93
x2 = 1.08

x1_traj_a,x2_traj_a = affine_scaling(c,A,b, x0)

x1_traj_p,x2_traj_p = primal_path_following(c,A,b, x0)
fig = figure()
plot(x1_traj_a,x2_traj_a,"o-", label = "Affine")

plot(x1_traj_p,x2_traj_p,"*-", label = "primal")
legend(loc = "upper right")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000011F1B983CD0>
